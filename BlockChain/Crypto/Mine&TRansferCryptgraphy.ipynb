# %% [markdown]
# Sanya Khare
#
# TCA2357045

# %%
import hashlib
import json
import random
from datetime import datetime

# %%
class Transaction:
    def __init__(self, sender, receiver, amount):
        self.sender = sender
        self.receiver = receiver
        self.amount = amount

    def to_dict(self):
        return {
            "sender": self.sender,
            "receiver": self.receiver,
            "amount": self.amount
        }

# %%
class Block:

    def __init__(self, index, transaction, previous_hash, miner):

        self.index = index
        self.timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self.transaction = transaction
        self.previous_hash = previous_hash
        self.miner = miner
        self.nonce = 0
        self.hash = self.calculate_hash()

    def calculate_hash(self):

        block_string = json.dumps({
            "index": self.index,
            "timestamp": self.timestamp,
            "transaction": self.transaction.to_dict(),
            "previous_hash": self.previous_hash,
            "nonce": self.nonce,
            "miner": self.miner
        }, sort_keys=True)

        return hashlib.sha256(block_string.encode()).hexdigest()

# %%
class Blockchain:

    difficulty = 4

    def __init__(self):

        self.chain = []

        self.balances = {
            "Alice": 100,
            "Bob": 80,
            "Charlie": 60
        }

        self.miners = [f"Miner{i}" for i in range(1, 11)]

        for m in self.miners:
            self.balances[m] = 0

        self.create_genesis_block()

    def create_genesis_block(self):
        genesis = Block(0, Transaction("Genesis","Network",0), "0", "Genesis")
        self.chain.append(genesis)

    def get_latest_block(self):
        return self.chain[-1]


    def validate_transaction(self, tx):

        if self.balances[tx.sender] < tx.amount:
            return False

        return True


    def proof_of_work(self, block):

        while block.hash[:Blockchain.difficulty] != "0" * Blockchain.difficulty:
            block.nonce += 1
            block.hash = block.calculate_hash()

        return block


    def mine_transaction(self, tx):

        miner = random.choice(self.miners)

        block = Block(
            len(self.chain),
            tx,
            self.get_latest_block().hash,
            miner
        )

        block = self.proof_of_work(block)

        self.chain.append(block)

        fee = tx.amount * 0.10   # 10% fee
        receiver_amount = tx.amount - fee

        self.balances[tx.sender] -= tx.amount
        self.balances[tx.receiver] += receiver_amount
        self.balances[miner] += fee

        self.print_block(block)


    def print_block(self, block):

        print("\n====================================")

        print("Block Number:", block.index)
        print("Timestamp:", block.timestamp)
        print("Miner:", block.miner)
        print("Nonce (Proof):", block.nonce)

        print("\nTransactions")
        print(f"{block.transaction.sender} → {block.transaction.receiver} : {block.transaction.amount}")
        fee = block.transaction.amount * 0.10

        print("Transaction Amount:", block.transaction.amount)
        print("Miner Fee (10%):", fee)
        print("Receiver Gets:", block.transaction.amount - fee)
        print("Balances After Transaction:")
        for user, balance in self.balances.items():
            print(f"  {user}: {balance}")

        print("\nPrevious Hash:", block.previous_hash)
        print("Block Hash:", block.hash)

        print("====================================\n")

# %%
print("Satwik Saxena")
print("TCA2357046")
blockchain = Blockchain()

users = ["Alice","Bob","Charlie"]

# Mine 10 transactions → 10 blocks
for i in range(10):

    sender = random.choice(users)
    receiver = random.choice([u for u in users if u != sender])

    amount = random.randint(1,10)

    tx = Transaction(sender,receiver,amount)

    blockchain.mine_transaction(tx)
# Out:
# Sanya Khare
# TCA2357045
#
# ====================================
# Block Number: 1
# Timestamp: 2026-03-22 23:32:43
# Miner: Miner5
# Nonce (Proof): 7569
#
# Transactions
# Charlie → Alice : 5
# Transaction Amount: 5
# Miner Fee (10%): 0.5
# Receiver Gets: 4.5
# Balances After Transaction:
#   Alice: 104.5
#   Bob: 80
#   Charlie: 55
#   Miner1: 0
#   Miner2: 0
#   Miner3: 0
#   Miner4: 0
#   Miner5: 0.5
#   Miner6: 0
#   Miner7: 0
#   Miner8: 0
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: ca043d739ec89116724012abd2836b3d26930e06e31f3ec3b6aded7e4e5d84d4
# Block Hash: 00008c49bd979e7655aeffc224f1d22767c992eaf87f0cbf0dd705822bd1aa57
# ====================================
#
#
# ====================================
# Block Number: 2
# Timestamp: 2026-03-22 23:32:43
# Miner: Miner3
# Nonce (Proof): 97137
#
# Transactions
# Bob → Alice : 3
# Transaction Amount: 3
# Miner Fee (10%): 0.30000000000000004
# Receiver Gets: 2.7
# Balances After Transaction:
#   Alice: 107.2
#   Bob: 77
#   Charlie: 55
#   Miner1: 0
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 0.5
#   Miner6: 0
#   Miner7: 0
#   Miner8: 0
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 00008c49bd979e7655aeffc224f1d22767c992eaf87f0cbf0dd705822bd1aa57
# Block Hash: 0000fc18fc15bf2fabd5cba4acda1d70552abfdabc0bf3308c826fc7b22e1c0a
# ====================================
#
#
# ====================================
# Block Number: 3
# Timestamp: 2026-03-22 23:32:43
# Miner: Miner1
# Nonce (Proof): 12563
#
# Transactions
# Charlie → Alice : 1
# Transaction Amount: 1
# Miner Fee (10%): 0.1
# Receiver Gets: 0.9
# Balances After Transaction:
#   Alice: 108.10000000000001
#   Bob: 77
#   Charlie: 54
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 0.5
#   Miner6: 0
#   Miner7: 0
#   Miner8: 0
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 0000fc18fc15bf2fabd5cba4acda1d70552abfdabc0bf3308c826fc7b22e1c0a
# Block Hash: 0000d8618a5bf629edb7ed6264890c3edff4bfa002833987cb8ac30cf37cbf80
# ====================================
#
#
# ====================================
# Block Number: 4
# Timestamp: 2026-03-22 23:32:44
# Miner: Miner8
# Nonce (Proof): 145179
#
# Transactions
# Bob → Charlie : 9
# Transaction Amount: 9
# Miner Fee (10%): 0.9
# Receiver Gets: 8.1
# Balances After Transaction:
#   Alice: 108.10000000000001
#   Bob: 68
#   Charlie: 62.1
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 0.5
#   Miner6: 0
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 0000d8618a5bf629edb7ed6264890c3edff4bfa002833987cb8ac30cf37cbf80
# Block Hash: 000041009a85d80cbfef68de8853e5a6d1d52505dfb05648a197e3b4e911c15f
# ====================================
#
#
# ====================================
# Block Number: 5
# Timestamp: 2026-03-22 23:32:45
# Miner: Miner5
# Nonce (Proof): 3505
#
# Transactions
# Alice → Bob : 10
# Transaction Amount: 10
# Miner Fee (10%): 1.0
# Receiver Gets: 9.0
# Balances After Transaction:
#   Alice: 98.10000000000001
#   Bob: 77.0
#   Charlie: 62.1
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 1.5
#   Miner6: 0
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 000041009a85d80cbfef68de8853e5a6d1d52505dfb05648a197e3b4e911c15f
# Block Hash: 0000b8b47dc26681e7c39e4d2088113e68ec2e0d56c516bbde625fe10d6c31c6
# ====================================
#
#
# ====================================
# Block Number: 6
# Timestamp: 2026-03-22 23:32:45
# Miner: Miner6
# Nonce (Proof): 13027
#
# Transactions
# Alice → Charlie : 3
# Transaction Amount: 3
# Miner Fee (10%): 0.30000000000000004
# Receiver Gets: 2.7
# Balances After Transaction:
#   Alice: 95.10000000000001
#   Bob: 77.0
#   Charlie: 64.8
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 1.5
#   Miner6: 0.30000000000000004
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 0000b8b47dc26681e7c39e4d2088113e68ec2e0d56c516bbde625fe10d6c31c6
# Block Hash: 00004c6b430af90f216a3176a99dbc5ac844ebb1de38adf84941a1246baa16ce
# ====================================
#
#
# ====================================
# Block Number: 7
# Timestamp: 2026-03-22 23:32:45
# Miner: Miner5
# Nonce (Proof): 102606
#
# Transactions
# Alice → Bob : 5
# Transaction Amount: 5
# Miner Fee (10%): 0.5
# Receiver Gets: 4.5
# Balances After Transaction:
#   Alice: 90.10000000000001
#   Bob: 81.5
#   Charlie: 64.8
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 2.0
#   Miner6: 0.30000000000000004
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 00004c6b430af90f216a3176a99dbc5ac844ebb1de38adf84941a1246baa16ce
# Block Hash: 0000ccaef0cbe85e7a93c41f66d743f0a60fdac55026da48cd8d5ed7306de638
# ====================================
#
#
# ====================================
# Block Number: 8
# Timestamp: 2026-03-22 23:32:46
# Miner: Miner5
# Nonce (Proof): 146705
#
# Transactions
# Alice → Charlie : 7
# Transaction Amount: 7
# Miner Fee (10%): 0.7000000000000001
# Receiver Gets: 6.3
# Balances After Transaction:
#   Alice: 83.10000000000001
#   Bob: 81.5
#   Charlie: 71.1
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0
#   Miner5: 2.7
#   Miner6: 0.30000000000000004
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 0000ccaef0cbe85e7a93c41f66d743f0a60fdac55026da48cd8d5ed7306de638
# Block Hash: 000013f262b224ad5672cd4ed1e24cd72ee82bd567c85992ec5623183b8664d0
# ====================================
#
#
# ====================================
# Block Number: 9
# Timestamp: 2026-03-22 23:32:47
# Miner: Miner4
# Nonce (Proof): 48956
#
# Transactions
# Bob → Charlie : 4
# Transaction Amount: 4
# Miner Fee (10%): 0.4
# Receiver Gets: 3.6
# Balances After Transaction:
#   Alice: 83.10000000000001
#   Bob: 77.5
#   Charlie: 74.69999999999999
#   Miner1: 0.1
#   Miner2: 0
#   Miner3: 0.30000000000000004
#   Miner4: 0.4
#   Miner5: 2.7
#   Miner6: 0.30000000000000004
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 000013f262b224ad5672cd4ed1e24cd72ee82bd567c85992ec5623183b8664d0
# Block Hash: 0000d538d06f27876aba55aa298cb526689f68e5f8fb15b60032073313f2c31f
# ====================================
#
#
# ====================================
# Block Number: 10
# Timestamp: 2026-03-22 23:32:47
# Miner: Miner2
# Nonce (Proof): 109824
#
# Transactions
# Charlie → Bob : 4
# Transaction Amount: 4
# Miner Fee (10%): 0.4
# Receiver Gets: 3.6
# Balances After Transaction:
#   Alice: 83.10000000000001
#   Bob: 81.1
#   Charlie: 70.69999999999999
#   Miner1: 0.1
#   Miner2: 0.4
#   Miner3: 0.30000000000000004
#   Miner4: 0.4
#   Miner5: 2.7
#   Miner6: 0.30000000000000004
#   Miner7: 0
#   Miner8: 0.9
#   Miner9: 0
#   Miner10: 0
#
# Previous Hash: 0000d538d06f27876aba55aa298cb526689f68e5f8fb15b60032073313f2c31f
# Block Hash: 0000ebf246a70eecede50fdfe6c260fda90ce290df5aeb309d5c7754887467ee
# ====================================
